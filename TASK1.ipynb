# %%
# 1.VARIABLE

#1.create variable name pi and store the value 22/7 in it.
print("1.VARIABLES")
pi = 22 / 7
print(type(pi))  

# 2. Create a variable called `for` and assign it a value of `4`.
for_= 4  # for=4 will  raise a SyntaxError
print(for_)
# 3. Store the principal amount, rate of interest, and time in different variables and calculate Simple Interst for 3 years.
P = 1000  
R = 5     
T = 3     
Simple_Interest = P * R * T / 100
print(Simple_Interest)  
import math
print("______________________________________________________________________________________________________________________________________________")

#2.NUMBERS

# 1. Write a function th  at takes two arguments and uses the `format` function.
print("2.NUMBERS")
def formatstring(number, character):
    return "The number is {} and the character is '{}'".format(number, character)
result = format_string(145, 'o')
print(result)  

# 2. Calculate the area of a circular pond with a radius of 84 meters.
radius = 84
pi = 3.14
Area = pi * radius ** 2
print(Area)  
# Bonus: Total amount of water in the pond
water_per_sqm = 1.4
total_water = Area * water_per_sqm
print(int(total_water))  

# 3. Calculate your speed if you cross a 490-meter-long street in 7 minutes.
distance = 490
Time_in_Minutes = 7
Time_in_Seconds = Time_in_Minutes * 60
speed = distance / Time_in_Seconds
print(int(speed))
print("______________________________________________________________________________________________________________________________________________")

#3.LIST OPERATION

# 1. Calculate the number of members in the Justice League.
print("3.LIST")
justice_league = ["Superman", "Batman", "Wonder Woman", "Flash", "Aquaman", "Green Lantern"]
print(len(justice_league))  

# 2. Add Batgirl and Nightwing to the list.
justice_league.append("Batgirl")
justice_league.append("Nightwing")
print(justice_league)  

# 3. Move Wonder Woman to the beginning of the list.
justice_league.remove("Wonder Woman")
justice_league.insert(0, "Wonder Woman")
print(justice_league)

# 4. Move either "Green Lantern" or "Superman" between Aquaman and Flash.
index_aquaman = justice_league.index("Aquaman")
index_flash = justice_league.index("Flash")
# Move Green Lantern between Aquaman and Flash
justice_league.remove("Green Lantern")
justice_league.insert(index_flash, "Green Lantern")
print(justice_league)  

# 5. Replace the existing list with new members.
new_members = ["Cyborg", "Shazam", "Hawkgirl", "Martian Manhunter", "Green Arrow"]
justice_league = new_members
print(justice_league)  

# 6. Sort the list alphabetically and determine the new leader.
justice_league.sort()
new_leader = justice_league[0]
print(justice_league)
print("New leader:", new_leader)
print("______________________________________________________________________________________________________________________________________________")

4.#IF CODITION

# 1. Determine the BMI Category.
print("4.IF CONDITION")
height = float(input("Enter height in meters: "))
weight = float(input("Enter weight in kilograms: "))
BMI = weight / (height ** 2)
if BMI >= 30:
    print("Obesity")
elif 25 <= BMI < 30:
    print("Overweight")
elif 18.5 <= BMI < 25:
    print("Normal")
else:
    print("Underweight")

# 2. Determine which country a city belongs to.
Australia = ["Sydney", "Melbourne", "Brisbane", "Perth"]
Uae = ["Dubai", "Abu Dhabi", "Sharjah", "Ajman"]
India = ["Mumbai", "Bangalore", "Chennai", "Delhi"]
city = input("Enter a city name: ")
if city in Australia:
    print(f"{city} is in Australia")
elif city in Uae:
    print(f"{city} is in UAE")
elif city in India:
    print(f"{city} is in India")
else:
    print("City not found")

# 3. Check if two cities belong to the same country.
city1 = input("Enter the first city: ")
city2 = input("Enter the second city: ")
if city1 in australia and city2 in australia:
    print("Both cities are in Australia")
elif city1 in uae and city2 in uae:
    print("Both cities are in UAE")
elif city1 in india and city2 in india:
    print("Both cities are in India")
else:
    print("They don't belong to the same country")
print("______________________________________________________________________________________________________________________________________________")

#5.DICTIONARY

# 1. Create a list of friends' names and tuples with name and length.
print("5.DICTIONARY")
friends = ["Deepika", "Harini", "Srimathi", "Haripriya", "Nithiya"]
friends_tuples = [(name, len(name)) for name in friends]
print(friends_tuples)  # Output: [('Alice', 5), ('Bob', 3), ('Charlie', 7), ('Diana', 4), ('Eve', 3)]

# 2. Track expenses and calculate totals.
your_expenses = {
    "Hotel": 1200,
    "Food": 800,
    "Transportation": 500,
    "Attractions": 300,
    "Miscellaneous": 200
}

partner_expenses = {
    "Hotel": 1000,
    "Food": 900,
    "Transportation": 600,
    "Attractions": 400,
    "Miscellaneous": 150
}

total_your_expenses = sum(your_expenses.values())
total_partner_expenses = sum(partner_expenses.values())

print(f"Your total expenses: {total_your_expenses}")
print(f"Partner's total expenses: {total_partner_expenses}")

if total_your_expenses > total_partner_expenses:
    print("You spent more money overall.")
else:
    print("Your partner spent more money overall.")

# Significant difference in spending
diff_category = max(your_expenses, key=lambda k: abs(your_expenses[k] - partner_expenses[k]))
diff_amount = abs(your_expenses[diff_category] - partner_expenses[diff_category])

print(f"Category with significant difference: {diff_category}")
print(f"Difference amount: {diff_amount}")
print("____________________________________________________________________________________________________________________________________________")
# Out:
# 1.VARIABLES
# <class 'float'>
# 4
# 150.0
# ______________________________________________________________________________________________________________________________________________
# 2.NUMBERS
# The number is 145 and the character is 'o'
# 22155.84
# 31018
# 1
# ______________________________________________________________________________________________________________________________________________
# 3.LIST
# 6
# ['Superman', 'Batman', 'Wonder Woman', 'Flash', 'Aquaman', 'Green Lantern', 'Batgirl', 'Nightwing']
# ['Wonder Woman', 'Superman', 'Batman', 'Flash', 'Aquaman', 'Green Lantern', 'Batgirl', 'Nightwing']
# ['Wonder Woman', 'Superman', 'Batman', 'Green Lantern', 'Flash', 'Aquaman', 'Batgirl', 'Nightwing']
# ['Cyborg', 'Shazam', 'Hawkgirl', 'Martian Manhunter', 'Green Arrow']
# ['Cyborg', 'Green Arrow', 'Hawkgirl', 'Martian Manhunter', 'Shazam']
# New leader: Cyborg
# ...
